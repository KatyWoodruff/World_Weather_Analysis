# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import gmaps
from citipy import citipy
# Import the requests library.
import requests

# Import the API key
from config import weather_api_key
from config import g_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Configure gmaps to use your Google API key.
gmaps.configure(api_key=g_key)

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 735

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Weather": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kapaa
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | nome
# Processing Record 4 of Set 1 | mataura
# Processing Record 5 of Set 1 | jabiru
# City not found. Skipping...
# Processing Record 6 of Set 1 | cuamba
# Processing Record 7 of Set 1 | rawson
# Processing Record 8 of Set 1 | castro
# Processing Record 9 of Set 1 | los llanos de aridane
# Processing Record 10 of Set 1 | klaksvik
# Processing Record 11 of Set 1 | atuona
# Processing Record 12 of Set 1 | jamestown
# Processing Record 13 of Set 1 | upernavik
# Processing Record 14 of Set 1 | puerto ayora
# Processing Record 15 of Set 1 | port lincoln
# Processing Record 16 of Set 1 | suzun
# Processing Record 17 of Set 1 | butaritari
# Processing Record 18 of Set 1 | port alfred
# Processing Record 19 of Set 1 | busselton
# Processing Record 20 of Set 1 | kuche
# City not found. Skipping...
# Processing Record 21 of Set 1 | bredasdorp
# Processing Record 22 of Set 1 | port elizabeth
# Processing Record 23 of Set 1 | tasiilaq
# Processing Record 24 of Set 1 | albany
# Processing Record 25 of Set 1 | faanui
# Processing Record 26 of Set 1 | hermanus
# Processing Record 27 of Set 1 | bluff
# Processing Record 28 of Set 1 | ushuaia
# Processing Record 29 of Set 1 | punta arenas
# Processing Record 30 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 31 of Set 1 | ancud
# Processing Record 32 of Set 1 | brownsville
# Processing Record 33 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 34 of Set 1 | hilo
# Processing Record 35 of Set 1 | marrakesh
# Processing Record 36 of Set 1 | taltal
# Processing Record 37 of Set 1 | ostrovnoy
# Processing Record 38 of Set 1 | vaini
# Processing Record 39 of Set 1 | cam pha
# City not found. Skipping...
# Processing Record 40 of Set 1 | saint-philippe
# Processing Record 41 of Set 1 | norman wells
# Processing Record 42 of Set 1 | shingu
# Processing Record 43 of Set 1 | san lawrenz
# Processing Record 44 of Set 1 | betong
# Processing Record 45 of Set 1 | san andres
# Processing Record 46 of Set 1 | aykhal
# Processing Record 47 of Set 1 | tual
# Processing Record 48 of Set 1 | guane
# Processing Record 49 of Set 1 | lompoc
# Processing Record 50 of Set 1 | yumen
# Processing Record 1 of Set 2 | yellowknife
# Processing Record 2 of Set 2 | carnarvon
# Processing Record 3 of Set 2 | san lazaro
# Processing Record 4 of Set 2 | saskylakh
# Processing Record 5 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 2 | fujieda
# Processing Record 7 of Set 2 | georgetown
# Processing Record 8 of Set 2 | mayumba
# Processing Record 9 of Set 2 | chuy
# Processing Record 10 of Set 2 | odweyne
# Processing Record 11 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 2 | qaanaaq
# Processing Record 13 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 14 of Set 2 | labuhan
# Processing Record 15 of Set 2 | lebu
# Processing Record 16 of Set 2 | bengkulu
# Processing Record 17 of Set 2 | guerrero negro
# Processing Record 18 of Set 2 | hokitika
# Processing Record 19 of Set 2 | saldanha
# Processing Record 20 of Set 2 | stanger
# Processing Record 21 of Set 2 | arraial do cabo
# Processing Record 22 of Set 2 | dali
# Processing Record 23 of Set 2 | souillac
# Processing Record 24 of Set 2 | qasigiannguit
# Processing Record 25 of Set 2 | higuey
# City not found. Skipping...
# Processing Record 26 of Set 2 | dauphin
# Processing Record 27 of Set 2 | salalah
# Processing Record 28 of Set 2 | east london
# Processing Record 29 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 30 of Set 2 | belaya gora
# Processing Record 31 of Set 2 | srikakulam
# Processing Record 32 of Set 2 | kuusamo
# Processing Record 33 of Set 2 | leningradskiy
# Processing Record 34 of Set 2 | new norfolk
# Processing Record 35 of Set 2 | andenes
# Processing Record 36 of Set 2 | pitimbu
# Processing Record 37 of Set 2 | kota kinabalu
# Processing Record 38 of Set 2 | chivay
# Processing Record 39 of Set 2 | chokurdakh
# Processing Record 40 of Set 2 | kushima
# Processing Record 41 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 42 of Set 2 | saint george
# Processing Record 43 of Set 2 | gryazi
# Processing Record 44 of Set 2 | hami
# Processing Record 45 of Set 2 | verkhniy ufaley
# Processing Record 46 of Set 2 | shenjiamen
# Processing Record 47 of Set 2 | kabare
# Processing Record 48 of Set 2 | taburi
# City not found. Skipping...
# Processing Record 49 of Set 2 | wittenberge
# Processing Record 50 of Set 2 | calabazar de sagua
# Processing Record 1 of Set 3 | atambua
# Processing Record 2 of Set 3 | puerto madryn
# Processing Record 3 of Set 3 | namatanai
# Processing Record 4 of Set 3 | iqaluit
# Processing Record 5 of Set 3 | te anau
# Processing Record 6 of Set 3 | vysokogornyy
# Processing Record 7 of Set 3 | flin flon
# Processing Record 8 of Set 3 | kohima
# Processing Record 9 of Set 3 | codrington
# Processing Record 10 of Set 3 | bandarbeyla
# Processing Record 11 of Set 3 | dubbo
# Processing Record 12 of Set 3 | maceio
# Processing Record 13 of Set 3 | puerto colombia
# Processing Record 14 of Set 3 | rawannawi
# City not found. Skipping...
# Processing Record 15 of Set 3 | naqadeh
# Processing Record 16 of Set 3 | lazaro cardenas
# Processing Record 17 of Set 3 | katsuura
# Processing Record 18 of Set 3 | pundaguitan
# Processing Record 19 of Set 3 | harrisonburg
# Processing Record 20 of Set 3 | vyritsa
# Processing Record 21 of Set 3 | goderich
# Processing Record 22 of Set 3 | puerto escondido
# Processing Record 23 of Set 3 | coihaique
# Processing Record 24 of Set 3 | nikolskoye
# Processing Record 25 of Set 3 | aswan
# Processing Record 26 of Set 3 | kahta
# Processing Record 27 of Set 3 | biak
# Processing Record 28 of Set 3 | gat
# Processing Record 29 of Set 3 | cidreira
# Processing Record 30 of Set 3 | paris
# Processing Record 31 of Set 3 | dikson
# Processing Record 32 of Set 3 | spring hill
# Processing Record 33 of Set 3 | avarua
# Processing Record 34 of Set 3 | mahadday weyne
# City not found. Skipping...
# Processing Record 35 of Set 3 | klyuchi
# Processing Record 36 of Set 3 | cape town
# Processing Record 37 of Set 3 | pisco
# Processing Record 38 of Set 3 | nanortalik
# Processing Record 39 of Set 3 | novopokrovskaya
# Processing Record 40 of Set 3 | miri
# Processing Record 41 of Set 3 | kruisfontein
# Processing Record 42 of Set 3 | ahipara
# Processing Record 43 of Set 3 | victoria
# Processing Record 44 of Set 3 | san patricio
# Processing Record 45 of Set 3 | mount gambier
# Processing Record 46 of Set 3 | pangnirtung
# Processing Record 47 of Set 3 | mitchell
# Processing Record 48 of Set 3 | takoradi
# Processing Record 49 of Set 3 | chadiza
# Processing Record 50 of Set 3 | geraldton
# Processing Record 1 of Set 4 | vao
# Processing Record 2 of Set 4 | manama
# Processing Record 3 of Set 4 | barrow
# Processing Record 4 of Set 4 | tuatapere
# Processing Record 5 of Set 4 | tuktoyaktuk
# Processing Record 6 of Set 4 | san carlos de bariloche
# Processing Record 7 of Set 4 | moose factory
# Processing Record 8 of Set 4 | vila franca do campo
# Processing Record 9 of Set 4 | qobustan
# Processing Record 10 of Set 4 | umm lajj
# Processing Record 11 of Set 4 | omama
# Processing Record 12 of Set 4 | willmar
# Processing Record 13 of Set 4 | hobart
# Processing Record 14 of Set 4 | kifri
# Processing Record 15 of Set 4 | hithadhoo
# Processing Record 16 of Set 4 | baherden
# Processing Record 17 of Set 4 | provideniya
# Processing Record 18 of Set 4 | hambantota
# Processing Record 19 of Set 4 | thompson
# Processing Record 20 of Set 4 | palaiokhora
# City not found. Skipping...
# Processing Record 21 of Set 4 | longyearbyen
# Processing Record 22 of Set 4 | oranjestad
# Processing Record 23 of Set 4 | filingue
# Processing Record 24 of Set 4 | tiznit
# Processing Record 25 of Set 4 | poyarkovo
# Processing Record 26 of Set 4 | troy
# Processing Record 27 of Set 4 | carutapera
# Processing Record 28 of Set 4 | houston
# Processing Record 29 of Set 4 | hay river
# Processing Record 30 of Set 4 | sidrolandia
# Processing Record 31 of Set 4 | vardo
# Processing Record 32 of Set 4 | contamana
# Processing Record 33 of Set 4 | puerto suarez
# Processing Record 34 of Set 4 | zonalnaya stantsiya
# Processing Record 35 of Set 4 | harper
# Processing Record 36 of Set 4 | fortuna
# Processing Record 37 of Set 4 | ilulissat
# Processing Record 38 of Set 4 | bambous virieux
# Processing Record 39 of Set 4 | ribeira grande
# Processing Record 40 of Set 4 | sorong
# Processing Record 41 of Set 4 | coracora
# Processing Record 42 of Set 4 | ashqelon
# Processing Record 43 of Set 4 | chifeng
# Processing Record 44 of Set 4 | hamilton
# Processing Record 45 of Set 4 | alice
# Processing Record 46 of Set 4 | ust-kulom
# Processing Record 47 of Set 4 | qaqortoq
# Processing Record 48 of Set 4 | margate
# Processing Record 49 of Set 4 | poum
# Processing Record 50 of Set 4 | severo-kurilsk
# Processing Record 1 of Set 5 | port blair
# Processing Record 2 of Set 5 | inhambane
# Processing Record 3 of Set 5 | arras
# Processing Record 4 of Set 5 | oxford
# Processing Record 5 of Set 5 | manono
# Processing Record 6 of Set 5 | mozarlandia
# Processing Record 7 of Set 5 | darhan
# Processing Record 8 of Set 5 | makamba
# Processing Record 9 of Set 5 | nelson bay
# Processing Record 10 of Set 5 | casper
# Processing Record 11 of Set 5 | ugoofaaru
# Processing Record 12 of Set 5 | grand-lahou
# Processing Record 13 of Set 5 | norrtalje
# Processing Record 14 of Set 5 | karratha
# Processing Record 15 of Set 5 | whitianga
# Processing Record 16 of Set 5 | necochea
# Processing Record 17 of Set 5 | nuevo progreso
# Processing Record 18 of Set 5 | artesia
# Processing Record 19 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 20 of Set 5 | roma
# Processing Record 21 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 5 | tautira
# Processing Record 23 of Set 5 | beyneu
# Processing Record 24 of Set 5 | lyuban
# Processing Record 25 of Set 5 | kaitangata
# Processing Record 26 of Set 5 | labrea
# Processing Record 27 of Set 5 | ribeira brava
# Processing Record 28 of Set 5 | kendari
# Processing Record 29 of Set 5 | bagdarin
# Processing Record 30 of Set 5 | saint-leu
# Processing Record 31 of Set 5 | corinto
# Processing Record 32 of Set 5 | grimari
# City not found. Skipping...
# Processing Record 33 of Set 5 | yerofey pavlovich
# Processing Record 34 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 35 of Set 5 | sept-iles
# Processing Record 36 of Set 5 | ponta do sol
# Processing Record 37 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 38 of Set 5 | mar del plata
# Processing Record 39 of Set 5 | nosy varika
# Processing Record 40 of Set 5 | barentu
# Processing Record 41 of Set 5 | broken hill
# Processing Record 42 of Set 5 | constitucion
# Processing Record 43 of Set 5 | saint-pierre
# Processing Record 44 of Set 5 | kodiak
# Processing Record 45 of Set 5 | beringovskiy
# Processing Record 46 of Set 5 | laurel
# Processing Record 47 of Set 5 | laguna de perlas
# Processing Record 48 of Set 5 | forest acres
# Processing Record 49 of Set 5 | kidal
# Processing Record 50 of Set 5 | sao gabriel da cachoeira
# Processing Record 1 of Set 6 | esperance
# Processing Record 2 of Set 6 | yanam
# Processing Record 3 of Set 6 | cherskiy
# Processing Record 4 of Set 6 | grandview
# Processing Record 5 of Set 6 | deputatskiy
# Processing Record 6 of Set 6 | kulim
# Processing Record 7 of Set 6 | bonthe
# Processing Record 8 of Set 6 | yarmouth
# Processing Record 9 of Set 6 | brae
# Processing Record 10 of Set 6 | ajdabiya
# Processing Record 11 of Set 6 | sidi ali
# Processing Record 12 of Set 6 | comodoro rivadavia
# Processing Record 13 of Set 6 | salina
# Processing Record 14 of Set 6 | bethel
# Processing Record 15 of Set 6 | clyde river
# Processing Record 16 of Set 6 | naze
# Processing Record 17 of Set 6 | tura
# Processing Record 18 of Set 6 | grand gaube
# Processing Record 19 of Set 6 | maymyo
# Processing Record 20 of Set 6 | praia
# Processing Record 21 of Set 6 | hvammstangi
# City not found. Skipping...
# Processing Record 22 of Set 6 | myaundzha
# Processing Record 23 of Set 6 | preobrazheniye
# Processing Record 24 of Set 6 | manggar
# Processing Record 25 of Set 6 | pevek
# Processing Record 26 of Set 6 | sinnamary
# Processing Record 27 of Set 6 | macia
# Processing Record 28 of Set 6 | vanino
# Processing Record 29 of Set 6 | canico
# Processing Record 30 of Set 6 | arcani
# Processing Record 31 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 32 of Set 6 | srbac
# Processing Record 33 of Set 6 | bakel
# Processing Record 34 of Set 6 | camocim
# Processing Record 35 of Set 6 | huejuquilla el alto
# Processing Record 36 of Set 6 | bucerias
# Processing Record 37 of Set 6 | anloga
# Processing Record 38 of Set 6 | palampur
# Processing Record 39 of Set 6 | vylgort
# City not found. Skipping...
# Processing Record 40 of Set 6 | chase
# Processing Record 41 of Set 6 | seoul
# Processing Record 42 of Set 6 | road town
# Processing Record 43 of Set 6 | port macquarie
# Processing Record 44 of Set 6 | port moresby
# Processing Record 45 of Set 6 | hervey bay
# Processing Record 46 of Set 6 | mutsamudu
# City not found. Skipping...
# Processing Record 47 of Set 6 | lancaster
# Processing Record 48 of Set 6 | dingle
# Processing Record 49 of Set 6 | hasaki
# Processing Record 50 of Set 6 | antalaha
# Processing Record 1 of Set 7 | talnakh
# Processing Record 2 of Set 7 | cayenne
# Processing Record 3 of Set 7 | darab
# Processing Record 4 of Set 7 | aripuana
# Processing Record 5 of Set 7 | la ronge
# Processing Record 6 of Set 7 | lumphat
# Processing Record 7 of Set 7 | bahir dar
# Processing Record 8 of Set 7 | narrabri
# Processing Record 9 of Set 7 | sitka
# Processing Record 10 of Set 7 | kloulklubed
# Processing Record 11 of Set 7 | katra
# Processing Record 12 of Set 7 | acapulco
# Processing Record 13 of Set 7 | lenger
# Processing Record 14 of Set 7 | sabha
# Processing Record 15 of Set 7 | luderitz
# Processing Record 16 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 17 of Set 7 | hirara
# Processing Record 18 of Set 7 | aguadilla
# Processing Record 19 of Set 7 | atlantic beach
# Processing Record 20 of Set 7 | bira
# Processing Record 21 of Set 7 | usinsk
# Processing Record 22 of Set 7 | roebourne
# Processing Record 23 of Set 7 | kahului
# Processing Record 24 of Set 7 | mnogovershinnyy
# Processing Record 25 of Set 7 | waddan
# Processing Record 26 of Set 7 | lagoa
# Processing Record 27 of Set 7 | amapa
# Processing Record 28 of Set 7 | hofn
# Processing Record 29 of Set 7 | sao filipe
# Processing Record 30 of Set 7 | znamenskoye
# Processing Record 31 of Set 7 | killarney
# Processing Record 32 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 33 of Set 7 | sola
# Processing Record 34 of Set 7 | tamala
# Processing Record 35 of Set 7 | kismayo
# Processing Record 36 of Set 7 | nouadhibou
# Processing Record 37 of Set 7 | sandviken
# Processing Record 38 of Set 7 | alyangula
# Processing Record 39 of Set 7 | hun
# Processing Record 40 of Set 7 | mayo
# Processing Record 41 of Set 7 | banda aceh
# Processing Record 42 of Set 7 | vostok
# Processing Record 43 of Set 7 | mogocha
# Processing Record 44 of Set 7 | alakurtti
# Processing Record 45 of Set 7 | esil
# Processing Record 46 of Set 7 | lashio
# Processing Record 47 of Set 7 | vanavara
# Processing Record 48 of Set 7 | tobol
# Processing Record 49 of Set 7 | hope
# Processing Record 50 of Set 7 | havre-saint-pierre
# Processing Record 1 of Set 8 | san juan
# Processing Record 2 of Set 8 | ilek
# Processing Record 3 of Set 8 | west bay
# Processing Record 4 of Set 8 | saint-francois
# Processing Record 5 of Set 8 | hagenow
# Processing Record 6 of Set 8 | suntar
# Processing Record 7 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 8 of Set 8 | chachapoyas
# Processing Record 9 of Set 8 | husavik
# Processing Record 10 of Set 8 | truckee
# Processing Record 11 of Set 8 | palmer
# Processing Record 12 of Set 8 | altamira
# Processing Record 13 of Set 8 | cabo san lucas
# Processing Record 14 of Set 8 | ulaanbaatar
# Processing Record 15 of Set 8 | vikhorevka
# Processing Record 16 of Set 8 | moree
# Processing Record 17 of Set 8 | noumea
# Processing Record 18 of Set 8 | bathsheba
# Processing Record 19 of Set 8 | moron
# Processing Record 20 of Set 8 | babanusah
# City not found. Skipping...
# Processing Record 21 of Set 8 | brigantine
# Processing Record 22 of Set 8 | fevralsk
# City not found. Skipping...
# Processing Record 23 of Set 8 | pavullo nel frignano
# Processing Record 24 of Set 8 | papayal
# Processing Record 25 of Set 8 | ucluelet
# Processing Record 26 of Set 8 | panshi
# Processing Record 27 of Set 8 | ola
# Processing Record 28 of Set 8 | vestmannaeyjar
# Processing Record 29 of Set 8 | iztapa
# Processing Record 30 of Set 8 | kavieng
# Processing Record 31 of Set 8 | khatanga
# Processing Record 32 of Set 8 | concepcion del oro
# Processing Record 33 of Set 8 | topolevo
# Processing Record 34 of Set 8 | weston
# Processing Record 35 of Set 8 | maragogi
# Processing Record 36 of Set 8 | razole
# Processing Record 37 of Set 8 | adrar
# Processing Record 38 of Set 8 | were ilu
# Processing Record 39 of Set 8 | ust-nera
# Processing Record 40 of Set 8 | gerash
# Processing Record 41 of Set 8 | zhuhai
# Processing Record 42 of Set 8 | arman
# Processing Record 43 of Set 8 | dudinka
# Processing Record 44 of Set 8 | caborca
# Processing Record 45 of Set 8 | port hardy
# Processing Record 46 of Set 8 | dwarka
# Processing Record 47 of Set 8 | lorengau
# Processing Record 48 of Set 8 | charters towers
# Processing Record 49 of Set 8 | awash
# Processing Record 50 of Set 8 | mwinilunga
# Processing Record 1 of Set 9 | lai
# Processing Record 2 of Set 9 | lumberton
# Processing Record 3 of Set 9 | aplahoue
# Processing Record 4 of Set 9 | gavrilov-yam
# Processing Record 5 of Set 9 | atherton
# Processing Record 6 of Set 9 | surt
# Processing Record 7 of Set 9 | port-de-paix
# City not found. Skipping...
# Processing Record 8 of Set 9 | calabozo
# Processing Record 9 of Set 9 | kasulu
# Processing Record 10 of Set 9 | datong
# Processing Record 11 of Set 9 | narathiwat
# Processing Record 12 of Set 9 | makakilo city
# Processing Record 13 of Set 9 | caravelas
# Processing Record 14 of Set 9 | asilah
# Processing Record 15 of Set 9 | luan
# Processing Record 16 of Set 9 | airai
# Processing Record 17 of Set 9 | ippy
# Processing Record 18 of Set 9 | gravdal
# Processing Record 19 of Set 9 | puri
# Processing Record 20 of Set 9 | ixtapa
# Processing Record 21 of Set 9 | thamaga
# Processing Record 22 of Set 9 | alta floresta
# Processing Record 23 of Set 9 | tarauaca
# Processing Record 24 of Set 9 | yulara
# Processing Record 25 of Set 9 | zyryanka
# Processing Record 26 of Set 9 | saint-augustin
# Processing Record 27 of Set 9 | susanville
# Processing Record 28 of Set 9 | fare
# Processing Record 29 of Set 9 | sungaipenuh
# Processing Record 30 of Set 9 | berdigestyakh
# Processing Record 31 of Set 9 | palmerston
# Processing Record 32 of Set 9 | gigmoto
# Processing Record 33 of Set 9 | mae ramat
# Processing Record 34 of Set 9 | taywarah
# Processing Record 35 of Set 9 | tiksi
# Processing Record 36 of Set 9 | narsaq
# Processing Record 37 of Set 9 | progreso
# Processing Record 38 of Set 9 | mutata
# Processing Record 39 of Set 9 | chapais
# Processing Record 40 of Set 9 | jalu
# Processing Record 41 of Set 9 | kamenka
# Processing Record 42 of Set 9 | noshiro
# Processing Record 43 of Set 9 | kavaratti
# Processing Record 44 of Set 9 | pincher creek
# Processing Record 45 of Set 9 | kyaikto
# Processing Record 46 of Set 9 | kralendijk
# Processing Record 47 of Set 9 | muros
# Processing Record 48 of Set 9 | tawnat
# City not found. Skipping...
# Processing Record 49 of Set 9 | karaton
# Processing Record 50 of Set 9 | huambo
# Processing Record 1 of Set 10 | tuggurt
# City not found. Skipping...
# Processing Record 2 of Set 10 | sucua
# Processing Record 3 of Set 10 | hopelchen
# Processing Record 4 of Set 10 | great falls
# Processing Record 5 of Set 10 | zhigansk
# Processing Record 6 of Set 10 | san mateo del mar
# Processing Record 7 of Set 10 | shimoda
# Processing Record 8 of Set 10 | rundu
# Processing Record 9 of Set 10 | doha
# Processing Record 10 of Set 10 | santos dumont
# Processing Record 11 of Set 10 | svetlyy
# Processing Record 12 of Set 10 | galle
# Processing Record 13 of Set 10 | werda
# Processing Record 14 of Set 10 | charkhi dadri
# Processing Record 15 of Set 10 | aklavik
# Processing Record 16 of Set 10 | general roca
# Processing Record 17 of Set 10 | touros
# Processing Record 18 of Set 10 | tucuman
# Processing Record 19 of Set 10 | torbay
# Processing Record 20 of Set 10 | teguise
# Processing Record 21 of Set 10 | jiangyou
# Processing Record 22 of Set 10 | severnyy
# Processing Record 23 of Set 10 | kambove
# Processing Record 24 of Set 10 | bridgetown
# Processing Record 25 of Set 10 | voskresenskoye
# Processing Record 26 of Set 10 | sao joao do paraiso
# Processing Record 27 of Set 10 | college
# Processing Record 28 of Set 10 | viedma
# Processing Record 29 of Set 10 | tommot
# Processing Record 30 of Set 10 | meulaboh
# Processing Record 31 of Set 10 | xiongyue
# Processing Record 32 of Set 10 | makokou
# Processing Record 33 of Set 10 | lokosovo
# Processing Record 34 of Set 10 | champerico
# Processing Record 35 of Set 10 | urucara
# Processing Record 36 of Set 10 | la macarena
# Processing Record 37 of Set 10 | nuuk
# Processing Record 38 of Set 10 | priiskovyy
# Processing Record 39 of Set 10 | mount isa
# Processing Record 40 of Set 10 | eston
# Processing Record 41 of Set 10 | mbandaka
# Processing Record 42 of Set 10 | carmelo
# Processing Record 43 of Set 10 | bourail
# Processing Record 44 of Set 10 | apalit
# Processing Record 45 of Set 10 | mahibadhoo
# Processing Record 46 of Set 10 | natal
# Processing Record 47 of Set 10 | hobyo
# Processing Record 48 of Set 10 | ossora
# Processing Record 49 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 50 of Set 10 | linping
# Processing Record 1 of Set 11 | olinda
# Processing Record 2 of Set 11 | mahebourg
# Processing Record 3 of Set 11 | jieshi
# Processing Record 4 of Set 11 | pangkalanbuun
# Processing Record 5 of Set 11 | yokadouma
# Processing Record 6 of Set 11 | lardos
# Processing Record 7 of Set 11 | ukiah
# Processing Record 8 of Set 11 | camacupa
# Processing Record 9 of Set 11 | kenai
# Processing Record 10 of Set 11 | baykit
# Processing Record 11 of Set 11 | tecoanapa
# Processing Record 12 of Set 11 | sao borja
# Processing Record 13 of Set 11 | zagora
# Processing Record 14 of Set 11 | namibe
# Processing Record 15 of Set 11 | faya
# Processing Record 16 of Set 11 | bar harbor
# Processing Record 17 of Set 11 | wethersfield
# Processing Record 18 of Set 11 | iquique
# Processing Record 19 of Set 11 | rio grande
# Processing Record 20 of Set 11 | attawapiskat
# City not found. Skipping...
# Processing Record 21 of Set 11 | zhanakorgan
# Processing Record 22 of Set 11 | borama
# City not found. Skipping...
# Processing Record 23 of Set 11 | tostamaa
# City not found. Skipping...
# Processing Record 24 of Set 11 | jiangkou
# Processing Record 25 of Set 11 | yeppoon
# Processing Record 26 of Set 11 | hurghada
# Processing Record 27 of Set 11 | laguna
# Processing Record 28 of Set 11 | mareeba
# Processing Record 29 of Set 11 | zhangye
# Processing Record 30 of Set 11 | yamada
# Processing Record 31 of Set 11 | cantagallo
# Processing Record 32 of Set 11 | jacareacanga
# Processing Record 33 of Set 11 | spirit river
# Processing Record 34 of Set 11 | macomer
# Processing Record 35 of Set 11 | juli
# Processing Record 36 of Set 11 | kununurra
# Processing Record 37 of Set 11 | komsomolskiy
# Processing Record 38 of Set 11 | the pas
# Processing Record 39 of Set 11 | smolenka
# Processing Record 40 of Set 11 | carahue
# Processing Record 41 of Set 11 | chicama
# Processing Record 42 of Set 11 | skjervoy
# Processing Record 43 of Set 11 | khuzhir
# Processing Record 44 of Set 11 | prince rupert
# Processing Record 45 of Set 11 | aleksandrov gay
# Processing Record 46 of Set 11 | burica
# City not found. Skipping...
# Processing Record 47 of Set 11 | vallenar
# Processing Record 48 of Set 11 | canton
# Processing Record 49 of Set 11 | uturoa
# Processing Record 50 of Set 11 | guymon
# Processing Record 1 of Set 12 | banikoara
# Processing Record 2 of Set 12 | taoudenni
# Processing Record 3 of Set 12 | boyolangu
# Processing Record 4 of Set 12 | ndele
# Processing Record 5 of Set 12 | bastrop
# Processing Record 6 of Set 12 | marzuq
# Processing Record 7 of Set 12 | sampit
# Processing Record 8 of Set 12 | balotra
# Processing Record 9 of Set 12 | rayagada
# Processing Record 10 of Set 12 | omsukchan
# Processing Record 11 of Set 12 | terra nova
# Processing Record 12 of Set 12 | pasighat
# Processing Record 13 of Set 12 | port hedland
# Processing Record 14 of Set 12 | ahuimanu
# Processing Record 15 of Set 12 | riberalta
# Processing Record 16 of Set 12 | koster
# Processing Record 17 of Set 12 | kibala
# Processing Record 18 of Set 12 | marfino
# Processing Record 19 of Set 12 | sangar
# Processing Record 20 of Set 12 | sorland
# Processing Record 21 of Set 12 | lohardaga
# Processing Record 22 of Set 12 | axim
# Processing Record 23 of Set 12 | chikoy
# City not found. Skipping...
# Processing Record 24 of Set 12 | severodvinsk
# Processing Record 25 of Set 12 | vaitape
# Processing Record 26 of Set 12 | metro
# Processing Record 27 of Set 12 | el alto
# Processing Record 28 of Set 12 | ponta grossa
# Processing Record 29 of Set 12 | uyuni
# Processing Record 30 of Set 12 | togul
# Processing Record 31 of Set 12 | plouzane
# Processing Record 32 of Set 12 | shakawe
# Processing Record 33 of Set 12 | sai buri
# Processing Record 34 of Set 12 | saint-joseph
# Processing Record 35 of Set 12 | kirakira
# Processing Record 36 of Set 12 | magadan
# Processing Record 37 of Set 12 | akyab
# Processing Record 38 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 39 of Set 12 | catuday
# Processing Record 40 of Set 12 | hualmay
# Processing Record 41 of Set 12 | foca
# Processing Record 42 of Set 12 | cao bang
# Processing Record 43 of Set 12 | meadow lake
# Processing Record 44 of Set 12 | naryan-mar
# Processing Record 45 of Set 12 | pingliang
# Processing Record 46 of Set 12 | fairbanks
# Processing Record 47 of Set 12 | asyut
# Processing Record 48 of Set 12 | veseloyarsk
# Processing Record 49 of Set 12 | cleethorpes
# Processing Record 50 of Set 12 | walvis bay
# Processing Record 1 of Set 13 | mossendjo
# Processing Record 2 of Set 13 | aioi
# Processing Record 3 of Set 13 | krasnoselkup
# Processing Record 4 of Set 13 | luis correia
# Processing Record 5 of Set 13 | itarema
# Processing Record 6 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 7 of Set 13 | praia da vitoria
# Processing Record 8 of Set 13 | nedryhayliv
# Processing Record 9 of Set 13 | sherman
# Processing Record 10 of Set 13 | palanca
# Processing Record 11 of Set 13 | mehamn
# Processing Record 12 of Set 13 | kaliua
# Processing Record 13 of Set 13 | kumluca
# Processing Record 14 of Set 13 | kyren
# Processing Record 15 of Set 13 | chateauneuf-les-martigues
# Processing Record 16 of Set 13 | jiehu
# Processing Record 17 of Set 13 | ryotsu
# Processing Record 18 of Set 13 | mae chan
# Processing Record 19 of Set 13 | kharakvasla
# Processing Record 20 of Set 13 | alice springs
# Processing Record 21 of Set 13 | bijela
# Processing Record 22 of Set 13 | abiy adi
# City not found. Skipping...
# Processing Record 23 of Set 13 | puerto ayacucho
# Processing Record 24 of Set 13 | toliary
# City not found. Skipping...
# Processing Record 25 of Set 13 | moranbah
# Processing Record 26 of Set 13 | devrek
# Processing Record 27 of Set 13 | humberto de campos
# Processing Record 28 of Set 13 | san quintin
# Processing Record 29 of Set 13 | mergui
# City not found. Skipping...
# Processing Record 30 of Set 13 | springbok
# Processing Record 31 of Set 13 | tsybuliv
# Processing Record 32 of Set 13 | sobolevo
# Processing Record 33 of Set 13 | katghora
# Processing Record 34 of Set 13 | nha trang
# Processing Record 35 of Set 13 | teguldet
# Processing Record 36 of Set 13 | benguela
# Processing Record 37 of Set 13 | yar-sale
# Processing Record 38 of Set 13 | neuquen
# Processing Record 39 of Set 13 | mittagong
# Processing Record 40 of Set 13 | christchurch
# Processing Record 41 of Set 13 | kasiri
# Processing Record 42 of Set 13 | wollongong
# Processing Record 43 of Set 13 | bardiyah
# Processing Record 44 of Set 13 | kinshasa
# Processing Record 45 of Set 13 | itaituba
# Processing Record 46 of Set 13 | visnes
# Processing Record 47 of Set 13 | solovetskiy
# City not found. Skipping...
# Processing Record 48 of Set 13 | rognan
# Processing Record 49 of Set 13 | ondorhaan
# City not found. Skipping...
# Processing Record 50 of Set 13 | kindu
# Processing Record 1 of Set 14 | iralaya
# Processing Record 2 of Set 14 | kostivere
# Processing Record 3 of Set 14 | biltine
# Processing Record 4 of Set 14 | bundaberg
# Processing Record 5 of Set 14 | palauig
# Processing Record 6 of Set 14 | fomboni
# Processing Record 7 of Set 14 | birjand
# Processing Record 8 of Set 14 | ormara
# Processing Record 9 of Set 14 | kikwit
# Processing Record 10 of Set 14 | witrivier
# City not found. Skipping...
# Processing Record 11 of Set 14 | north bend
# Processing Record 12 of Set 14 | erzin
# Processing Record 13 of Set 14 | vila velha
# Processing Record 14 of Set 14 | nan
# Processing Record 15 of Set 14 | samfya
# Processing Record 16 of Set 14 | kondinskoye
# Processing Record 17 of Set 14 | sesheke
# Processing Record 18 of Set 14 | camacari
# Processing Record 19 of Set 14 | izhma
# Processing Record 20 of Set 14 | lucea
# Processing Record 21 of Set 14 | zhumadian
# Processing Record 22 of Set 14 | kaduqli
# Processing Record 23 of Set 14 | teahupoo
# Processing Record 24 of Set 14 | zalantun
# Processing Record 25 of Set 14 | jaciara
# Processing Record 26 of Set 14 | lasa
# Processing Record 27 of Set 14 | badulla
# Processing Record 28 of Set 14 | hovd
# Processing Record 29 of Set 14 | farafangana
# Processing Record 30 of Set 14 | grand centre
# City not found. Skipping...
# Processing Record 31 of Set 14 | kysyl-syr
# Processing Record 32 of Set 14 | hailar
# Processing Record 33 of Set 14 | manjacaze
# Processing Record 34 of Set 14 | kargopol
# Processing Record 35 of Set 14 | burgeo
# Processing Record 36 of Set 14 | poya
# Processing Record 37 of Set 14 | bandar-e lengeh
# Processing Record 38 of Set 14 | srednekolymsk
# Processing Record 39 of Set 14 | kihei
# Processing Record 40 of Set 14 | verkhnyaya inta
# Processing Record 41 of Set 14 | sur
# Processing Record 42 of Set 14 | lithgow
# Processing Record 43 of Set 14 | imbituba
# Processing Record 44 of Set 14 | opuwo
# Processing Record 45 of Set 14 | chiredzi
# Processing Record 46 of Set 14 | nogliki
# Processing Record 47 of Set 14 | krasnoarmeysk
# Processing Record 48 of Set 14 | bud
# Processing Record 49 of Set 14 | beaverlodge
# Processing Record 50 of Set 14 | seminole
# Processing Record 1 of Set 15 | arona
# Processing Record 2 of Set 15 | asau
# Processing Record 3 of Set 15 | naftah
# City not found. Skipping...
# Processing Record 4 of Set 15 | beitbridge
# Processing Record 5 of Set 15 | maningrida
# Processing Record 6 of Set 15 | sherbakul
# Processing Record 7 of Set 15 | byron bay
# Processing Record 8 of Set 15 | esso
# Processing Record 9 of Set 15 | padang
# Processing Record 10 of Set 15 | mombetsu
# Processing Record 11 of Set 15 | sahrak
# City not found. Skipping...
# Processing Record 12 of Set 15 | chara
# Processing Record 13 of Set 15 | tonantins
# Processing Record 14 of Set 15 | gijon
# Processing Record 15 of Set 15 | soto la marina
# Processing Record 16 of Set 15 | yantal
# Processing Record 17 of Set 15 | kyabe
# Processing Record 18 of Set 15 | nesna
# Processing Record 19 of Set 15 | kieta
# Processing Record 20 of Set 15 | woodstock
# Processing Record 21 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 22 of Set 15 | changji
# Processing Record 23 of Set 15 | ambodifototra
# City not found. Skipping...
# Processing Record 24 of Set 15 | zhelyabovka
# Processing Record 25 of Set 15 | egvekinot
# Processing Record 26 of Set 15 | agadir
# Processing Record 27 of Set 15 | turukhansk
# Processing Record 28 of Set 15 | trieste
# Processing Record 29 of Set 15 | montrose
# Processing Record 30 of Set 15 | makaha
# Processing Record 31 of Set 15 | utiroa
# City not found. Skipping...
# Processing Record 32 of Set 15 | oistins
# Processing Record 33 of Set 15 | nhulunbuy
# Processing Record 34 of Set 15 | saint-paul
# Processing Record 35 of Set 15 | novobirilyussy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Weather"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#                     City Country      Lat       Lng  Max Temp  Humidity  \
# 0                  Kapaa      US  22.0752 -159.3190     80.58        77
# 1                Rikitea      PF -23.1203 -134.9692     74.10        73
# 2                   Nome      US  64.5011 -165.4064     48.27        81
# 3                Mataura      NZ -46.1927  168.8643     47.48        99
# 4                 Cuamba      MZ -14.8031   36.5372     68.68        50
# 5                 Rawson      AR -43.3002  -65.1023     46.04        77
# 6                 Castro      BR -24.7911  -50.0119     71.80        47
# 7  Los Llanos De Aridane      ES  28.6585  -17.9182     71.35        78
# 8               Klaksvik      FO  62.2266   -6.5890     52.72        85
# 9                 Atuona      PF  -9.8000 -139.0333     77.29        67
#
#    Cloudiness  Wind Speed   Current Weather
# 0          20       10.36        few clouds
# 1          98       12.73   overcast clouds
# 2         100        0.00   overcast clouds
# 3         100        1.68     moderate rain
# 4          95        7.18   overcast clouds
# 5         100       10.29   overcast clouds
# 6          42        5.97  scattered clouds
# 7           0       17.27         clear sky
# 8         100       12.17   overcast clouds
# 9          33       20.83  scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
